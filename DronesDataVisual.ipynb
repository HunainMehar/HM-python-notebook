# %%
import folium
import pandas as pd

# %%
pakistan_map = folium.Map(location=[30.3753, 69.3451], zoom_start=5, tiles='OpenStreetMap')

# %%
# df = pd.read_csv(r'C:\Users\Hunai\OneDrive\Documents\HM\Sem 8\Drones.csv',encoding = 'unicode_escape')
# print(df)
# Out:
#       S#                         Date   Time  \
# 0      1        Friday, June 18, 2004  22:00
# 1      2         Sunday, May 08, 2005  23:30
# 2      3  Thursday, December 01, 2005    NaN
# 3      4     Friday, January 06, 2006    NaN
# 4      5     Friday, January 13, 2006   3:00
# ..   ...                          ...    ...
# 415  402        Monday, June 12, 2017  21:00
# 416  403        Monday, July 03, 2017    NaN
# 417  404   Friday, September 15, 2017    NaN
# 418  405     Monday, October 16, 2017    NaN
# 419  NaN                          NaN    NaN
#
#                                  Location                 City Province  \
# 0                               Near Wana     south Waziristan     FATA
# 1            Mir Ali (Near Afghan Border)     North Waziristan     FATA
# 2                     Haisori- Miran Shah     North Waziristan     FATA
# 3    Saidgai village- 115km north of Wana     North Waziristan     FATA
# ...

# %%
t=0
for c in df['Total Died Max']:
    t= c + t
print(t)
# Out:
# nan

# %%
da=pd.read_csv(r'C:\Users\Hunai\OneDrive\Documents\HM\Sem 8\Drone2.csv',encoding = 'unicode_escape')
print(da)
# Out:
#       S#                         Date   Time  \
# 0      1        Friday, June 18, 2004  22:00
# 1      2         Sunday, May 08, 2005  23:30
# 2      3  Thursday, December 01, 2005    NaN
# 3      4     Friday, January 06, 2006    NaN
# 4      5     Friday, January 13, 2006   3:00
# ..   ...                          ...    ...
# 416  403         Monday July 03, 2017    NaN
# 417  404    Friday September 15, 2017    NaN
# 418  405      Monday October 16, 2017  17:37
# 419  406    Thursday November 30,2017   4:30
# 420  NaN                          NaN    NaN
#
#                                  Location                 City Province  \
# 0                               Near Wana     south Waziristan     FATA
# 1            Mir Ali (Near Afghan Border)     North Waziristan     FATA
# 2                     Haisori- Miran Shah     North Waziristan     FATA
# 3    Saidgai village- 115km north of Wana     North Waziristan     FATA
# ...

# %%
t=0
for c in da['Total Died Max']:
    t= c + t
print(t)
# Out:
# nan
